# %%
import pandas as pd
from pathlib import Path
from prefect_sqlalchemy import DatabaseCredentials

# %%
database_block = DatabaseCredentials.load("postgre")

# %%
database_block.get_engine()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 database_block.get_engine()
#
# AttributeError: 'coroutine' object has no attribute 'get_engine'

# %%
color = "green"
year = 2020
month = 1

# %%
dataset_file = f"{color}_tripdata_{year}-{month:02}"
dataset_url = f"https://github.com/DataTalksClub/nyc-tlc-data/releases/download/{color}/{dataset_file}.csv.gz"

# %%
dataset_url
# Out:
# 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2020-01.csv.gz'

# %%
pd.read_csv(dataset_url)
# Out:
# C:\Users\cross\AppData\Local\Temp\ipykernel_26496\3236508184.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(dataset_url)
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-12-18 15:52:30   2019-12-18 15:54:39
# 1            2.0  2020-01-01 00:45:58   2020-01-01 00:56:39
# 2            2.0  2020-01-01 00:41:38   2020-01-01 00:52:49
# 3            1.0  2020-01-01 00:52:46   2020-01-01 01:14:21
# 4            1.0  2020-01-01 00:19:57   2020-01-01 00:30:56
# ...          ...                  ...                   ...
# 447765       NaN  2020-01-31 23:29:00   2020-01-31 23:47:00
# 447766       NaN  2020-01-31 23:57:00   2020-02-01 00:23:00
# 447767       NaN  2020-01-31 23:57:00   2020-02-01 00:10:00
# 447768       NaN  2020-01-31 23:27:00   2020-02-01 00:04:00
# 447769       NaN  2020-01-31 23:36:00   2020-02-01 00:01:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           264           264
# 1                       N         5.0            66            65
# 2                       N         1.0           181           228
# 3                       N         1.0           129           263
# 4                       N         1.0           210           150
# ...                   ...         ...           ...           ...
# 447765                NaN         NaN           167            32
# 447766                NaN         NaN            81            69
# 447767                NaN         NaN           244           241
# 447768                NaN         NaN            68            17
# 447769                NaN         NaN            22           124
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                   5.0           0.00         3.50   0.50      0.5
# 1                   2.0           1.28        20.00   0.00      0.0
# 2                   1.0           2.47        10.50   0.50      0.5
# 3                   2.0           6.30        21.00   3.25      0.5
# 4                   1.0           2.30        10.00   0.50      0.5
# ...                 ...            ...          ...    ...      ...
# 447765              NaN           4.58        23.21   2.75      0.0
# 447766              NaN           6.55        27.27   2.75      0.0
# 447767              NaN           3.34        25.95   2.75      0.0
# 447768              NaN           8.92        30.39   2.75      0.0
# 447769              NaN          13.51        42.20   2.75      0.0
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             0.01           0.0        NaN                    0.3
# 1             4.06           0.0        NaN                    0.3
# 2             3.54           0.0        NaN                    0.3
# 3             0.00           0.0        NaN                    0.3
# 4             0.00           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 447765        0.00           0.0        NaN                    0.3
# 447766        0.00           0.0        NaN                    0.3
# 447767        0.00           0.0        NaN                    0.3
# 447768        0.00           0.0        NaN                    0.3
# 447769        0.00           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0               4.81           1.0        1.0                  0.00
# 1              24.36           1.0        2.0                  0.00
# 2              15.34           1.0        1.0                  0.00
# 3              25.05           2.0        1.0                  2.75
# 4              11.30           1.0        1.0                  0.00
# ...              ...           ...        ...                   ...
# 447765         26.26           NaN        NaN                   NaN
# 447766         30.32           NaN        NaN                   NaN
# 447767         29.00           NaN        NaN                   NaN
# 447768         33.44           NaN        NaN                   NaN
# 447769         45.25           NaN        NaN                   NaN
#
# [447770 rows x 20 columns]

# %%
path = Path(f"data/{color}/{dataset_file}.parquet")

# %%
BASE_DIR = Path(__file__).resolve().parent.parent
TEMPLATES_DIR = BASE_DIR.joinpath('templates')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 BASE_DIR = Path(__file__).resolve().parent.parent
#       2 TEMPLATES_DIR = BASE_DIR.joinpath('templates')
#
# NameError: name '__file__' is not defined

# %%
import pathlib

p = pathlib.Path(__file__)
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pathlib
# ----> 3 p = pathlib.Path(__file__)
#       4 print(p)
#
# NameError: name '__file__' is not defined

# %%
import os
os.path.abspath('')
# Out:
# 'd:\\Dev\\datatalk\\week_2'
# При выполнении кода в текущей ячейке или предыдущей ячейке ядро аварийно завершило работу. Проверьте код в ячейках, чтобы определить возможную причину сбоя. Щелкните <a href="https://aka.ms/vscodeJupyterKernelCrash">здесь</a> для получения дополнительных сведений. Подробнее см. в <a href='command:jupyter.viewOutput'>журнале Jupyter</a>.
